# %%
import pandas as pd
df1 = pd.read_csv(r'E:datasets\drugs_for_common_treatments.csv')
df2=pd.read_excel(r'E:datasets\drugsss.xlsx') #scrapped dataset from internet(drugs.com)
df2
# Out:
#                                         drug_name        medical_condition  \
# 0                                   phenobarbital                 Jaundice
# 1                                  nitrofurantoin  Urinary tract infection
# 2                                   ciprofloxacin  Urinary tract infection
# 3                                        macrobid  Urinary tract infection
# 4                                           cipro  Urinary tract infection
# ..                                            ...                      ...
# 615                  Tylenol Plus Children's Cold              Common Cold
# 616                                       Vanacof              Common Cold
# 617                                       Vi-Sudo              Common Cold
# 618  Vicks Formula 44 Custom Care Cough & Cold PM              Common Cold
# 619                                    Zodryl DAC              Common Cold
#
# ...

# %%
df2 = df2.dropna(subset=["drug_name","medical_condition"])
df2
# Out:
#                                         drug_name        medical_condition  \
# 0                                   phenobarbital                 Jaundice
# 1                                  nitrofurantoin  Urinary tract infection
# 2                                   ciprofloxacin  Urinary tract infection
# 3                                        macrobid  Urinary tract infection
# 4                                           cipro  Urinary tract infection
# ..                                            ...                      ...
# 615                  Tylenol Plus Children's Cold              Common Cold
# 616                                       Vanacof              Common Cold
# 617                                       Vi-Sudo              Common Cold
# 618  Vicks Formula 44 Custom Care Cough & Cold PM              Common Cold
# 619                                    Zodryl DAC              Common Cold
#
# ...

# %%
print(df1.columns)
print(df2.columns)
# Out:
# Index(['drug_name', 'medical_condition', 'medical_condition_description',
#        'activity', 'rx_otc', 'pregnancy_category', 'csa', 'alcohol', 'rating',
#        'no_of_reviews', 'medical_condition_url', 'drug_link', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
# ...

# %%
df1=df1.drop(columns=['Unnamed: 12',
       'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
       'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
       'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
       'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
       'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
       'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
       'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
       'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
       'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
       'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
       'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
       'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59','medical_condition_description','csa','medical_condition_url', 'drug_link','rating', 'no_of_reviews'])
print(df1.columns)

df2=df2.drop(columns=['csa', 'rating', 'no_of_reviews', 'drug_link'])
print(df2.columns)
# Out:
# Index(['drug_name', 'medical_condition', 'activity', 'rx_otc',
#        'pregnancy_category', 'alcohol'],
#       dtype='object')
# Index(['drug_name', 'medical_condition', 'activity', 'rt_otc', 'pregnancy',
#        'alcohol'],
#       dtype='object')

# %%
# Rename the columns
df2 = df2.rename(columns={'rt_otc':'rx_otc','pregnancy':'pregnancy_category'})
print(df1.columns)
print(df2.columns)
# Out:
# Index(['drug_name', 'medical_condition', 'activity', 'rx_otc',
#        'pregnancy_category', 'alcohol'],
#       dtype='object')
# Index(['drug_name', 'medical_condition', 'activity', 'rx_otc',
#        'pregnancy_category', 'alcohol'],
#       dtype='object')

# %%
print(df1.dtypes)
print("_______________________")
print(df2.dtypes)
# Out:
# drug_name             object
# medical_condition     object
# activity              object
# rx_otc                object
# pregnancy_category    object
# alcohol               object
# dtype: object
# _______________________
# drug_name              object
# medical_condition      object
# activity              float64
# rx_otc                 object
# pregnancy_category     object
# alcohol                object
# dtype: object

# %%
# Remove the percentage symbol
df1['activity'] = df1['activity'].str.replace('%', '')
df1
# Out:
#            drug_name medical_condition activity rx_otc pregnancy_category  \
# 0        doxycycline              Acne       87     Rx                  D
# 1     spironolactone              Acne       82     Rx                  C
# 2        minocycline              Acne       48     Rx                  D
# 3           Accutane              Acne       41     Rx                  X
# 4        clindamycin              Acne       39     Rx                  B
# ...              ...               ...      ...    ...                ...
# 3988    fenfluramine       Weight Loss        1     Rx                  C
# 3989     Fendique ER       Weight Loss        0     Rx                  C
# 3990        Imcivree       Weight Loss        0     Rx                NaN
# 3991   setmelanotide       Weight Loss        0     Rx                NaN
# 3992     tirzepatide       Weight Loss        0     Rx                NaN
#
#      alcohol
# 0          X
# 1          X
# 2        NaN
# 3          X
# ...

# %%
# Merge the datasets based on a common key or index
md = pd.concat([df1, df2])
md
# Out:
#                                         drug_name medical_condition activity  \
# 0                                     doxycycline              Acne       87
# 1                                  spironolactone              Acne       82
# 2                                     minocycline              Acne       48
# 3                                        Accutane              Acne       41
# 4                                     clindamycin              Acne       39
# ..                                            ...               ...      ...
# 615                  Tylenol Plus Children's Cold       Common Cold      0.0
# 616                                       Vanacof       Common Cold      0.0
# 617                                       Vi-Sudo       Common Cold      0.0
# 618  Vicks Formula 44 Custom Care Cough & Cold PM       Common Cold      0.0
# 619                                    Zodryl DAC       Common Cold      0.0
#
#      rx_otc pregnancy_category alcohol
# ...

# %%
3993+620
# Out:
# 4613

# %%
# Count the number of NaN values in the column
nan_count = md['activity'].isna().sum()

# Print the number of NaN values
print("Number of NaN values in :", nan_count)
# Out:
# Number of NaN values in : 34

# %%
md=md.dropna(subset=['activity','pregnancy_category'])
md
# Out:
#                                         drug_name medical_condition activity  \
# 0                                     doxycycline              Acne       87
# 1                                  spironolactone              Acne       82
# 2                                     minocycline              Acne       48
# 3                                        Accutane              Acne       41
# 4                                     clindamycin              Acne       39
# ..                                            ...               ...      ...
# 615                  Tylenol Plus Children's Cold       Common Cold      0.0
# 616                                       Vanacof       Common Cold      0.0
# 617                                       Vi-Sudo       Common Cold      0.0
# 618  Vicks Formula 44 Custom Care Cough & Cold PM       Common Cold      0.0
# 619                                    Zodryl DAC       Common Cold      0.0
#
#      rx_otc pregnancy_category alcohol
# ...

# %%
# Rx_OTC

# Rx-to-OTC switch is the transfer of proven prescription drugs to nonprescription, where
# OTC (Over-the-counter) = Medication that can be purchased without a medical prescription
# Rx = Prescription Needed
# Rx/OTC = Prescription or Over-the-counter.

# pregnancy:

# A- no risk at first trimester of pregnancy by that drug
# B- by Animal studies:no risk on fetus (pregnant women)--no sufficient studies conducted in humans. 
# C- by Animal studies:risk on fetus but can use for potential benefits --no sufficient studies conducted in humans. 
# D- by Human studies: risk on fetus but can use for potential benefits
# X- Should not use by pregnant women
# N- not been classified by the FDA in terms of its safety during pregnancy

# PRIORITY(from safe to harmful):
#     A-B-C/D-N-X 
    
# alchohol:
    
# X- interacts with alcohol
# N -no alcohol interaction

# %%
md.rx_otc.value_counts()
# Out:
# Rx                                                            2734
# Rx/OTC                                                        1032
# OTC                                                            479
#  2021 Clover Pharmaceuticals announced that the randomized      34
# Rx                                                              34
# OTC                                                             15
# Rx                                                               1
# Name: rx_otc, dtype: int64

# %%
md['rx_otc'] = md['rx_otc'].str.strip()
md.rx_otc.value_counts()
# Out:
# D:\python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Rx                                                           2769
# Rx/OTC                                                       1032
# OTC                                                           494
# 2021 Clover Pharmaceuticals announced that the randomized      34
# Name: rx_otc, dtype: int64

# %%
# Drop rows based on the specified condition
md = md[md['rx_otc'] != "2021 Clover Pharmaceuticals announced that the randomized"]
md.rx_otc.value_counts()
# Out:
# Rx        2769
# Rx/OTC    1032
# OTC        494
# Name: rx_otc, dtype: int64

# %%
md.alcohol.value_counts()
# Out:
# X    2205
# N      56
# Name: alcohol, dtype: int64

# %%
md['alcohol'].fillna("N", inplace=True)
md.alcohol.value_counts()
# Out:
# D:\python\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# X    2205
# N    2091
# Name: alcohol, dtype: int64

# %%
md['activity'] = md['activity'].astype(int)
print(md.dtypes)
# Out:
# drug_name             object
# medical_condition     object
# activity               int32
# rx_otc                object
# pregnancy_category    object
# alcohol               object
# dtype: object
# D:\python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
md.to_csv('E:/datasets/rec-med.csv', index=False)

# %%
#finding how many diseases are covered(after scrapping(rec-med.csv) and before scrapping(dis-sym-cat))

# %%
import pandas as pd
md=pd.read_csv("E:/datasets/rec-med.csv")
list1=md.medical_condition.unique()
print(len(list1))
print(list1)
df=pd.read_csv("E:\datasets\dis-sym-cat.csv")
list2=df.Disease.unique()
print(len(list2))
print(list2)
# Out:
# 61
# ['Acne' 'ADHD' 'AIDS/HIV' 'Allergies' "Alzheimer's" 'Angina' 'Anxiety'
#  'Asthma' 'Bipolar Disorder' 'Bronchitis' 'Cancer' 'Cholesterol'
#  'Colds & Flu' 'Constipation' 'COPD' 'Depression' 'Diabetes (Type 1)'
#  'Diabetes (Type 2)' 'Diarrhea' 'Eczema' 'Erectile Dysfunction'
#  'Gastrointestinal' 'GERD (Heartburn)' 'Gout' 'Hair Loss' 'Hayfever'
#  'Herpes' 'Hypertension' 'Hypothyroidism' 'IBD (Bowel)' 'Incontinence'
#  'Insomnia' 'Menopause' 'Migraine' 'Osteoarthritis' 'Osteoporosis' 'Pain'
#  'Pneumonia' 'Psoriasis' 'Rheumatoid Arthritis' 'Schizophrenia' 'Seizures'
#  'Stroke' 'Swine Flu' 'UTI' 'Weight Loss' 'Jaundice'
#  'Urinary tract infection' 'Hepatitis A' 'Malaria' 'Peptic ulcer'
#  'Hypoglycemia' 'Hepatitis C' 'Varicose veins' 'Impetigo' 'Vertigo'
#  'Fungal Infections' 'Hepatitis B' 'Hemorrhoids' 'Myocardial infarction'
#  'Common Cold']
# 41
# ['Fungal infection' 'Allergy' 'GERD' 'Chronic cholestasis' 'Drug Reaction'
# ...

# %%
from fuzzywuzzy import fuzz

temp=[]
def print_similar_elements(list1, list2, similarity_threshold,c=0):

    for elmt1 in list1:
        for elmt2 in list2:
            token_set_ratio = fuzz.token_set_ratio(elmt1, elmt2)
            token_sort_ratio = fuzz.token_sort_ratio(elmt1, elmt2)
            wratio = fuzz.WRatio(elmt1, elmt2)

            # Return the maximum similarity score
            similarity_score=max(token_set_ratio, token_sort_ratio, wratio)
            if similarity_score > similarity_threshold:
                c+=1
                temp.append(elmt1)
                print(elmt1, "--", elmt2)
                break  # Break out of the inner loop after finding a match
    print("count:",c)
# Print similar elements with similarity above 70
similarity_threshold = 75
print_similar_elements(list2, list1, similarity_threshold,c=0)

print(temp)
# Out:
# D:\python\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# Fungal infection -- Fungal Infections
# GERD -- GERD (Heartburn)
# Peptic ulcer diseae -- Peptic ulcer
# AIDS -- AIDS/HIV
# Diabetes  -- Diabetes (Type 1)
# Bronchial Asthma -- Asthma
# Hypertension  -- Hypertension
# Migraine -- Migraine
# Jaundice -- Jaundice
# Malaria -- Malaria
# hepatitis A -- Hepatitis A
# Hepatitis B -- Hepatitis A
# Hepatitis C -- Hepatitis A
# Hepatitis D -- Hepatitis A
# Hepatitis E -- Hepatitis A
# Alcoholic hepatitis -- Hepatitis A
# Common Cold -- Common Cold
# Pneumonia -- Pneumonia
# Dimorphic hemmorhoids(piles) -- Hemorrhoids
# Varicose veins -- Varicose veins
# Hypothyroidism -- Hypothyroidism
# Hyperthyroidism -- Hypothyroidism
# Hypoglycemia -- Hypoglycemia
# ...

# %%
import pandas as pd
md=pd.read_csv('E:/datasets/rec-med.csv')
md
# Out:
#                                          drug_name medical_condition  \
# 0                                      doxycycline              Acne
# 1                                   spironolactone              Acne
# 2                                      minocycline              Acne
# 3                                         Accutane              Acne
# 4                                      clindamycin              Acne
# ...                                            ...               ...
# 4291                  Tylenol Plus Children's Cold       Common Cold
# 4292                                       Vanacof       Common Cold
# 4293                                       Vi-Sudo       Common Cold
# 4294  Vicks Formula 44 Custom Care Cough & Cold PM       Common Cold
# 4295                                    Zodryl DAC       Common Cold
#
#       activity  rx_otc pregnancy_category alcohol
# 0           87      Rx                  D       X
# ...

# %%
def recmedicine(disease,age,gender,pregnancy_condition,alcohol,duration):
    print(disease,age,gender,pregnancy_condition,alcohol,duration)
    
    
    # Filter the DataFrame based on the disease
    filtered_df = md[md['medical_condition'] == disease]
   

    if pregnancy_condition is not None:
        # Filter the DataFrame based on the allowed pregnancy categories
        filtered_df = filtered_df[filtered_df['pregnancy_category'].isin(allowed_pregnancy_category)]
    
    if alcohol is not None:
        # Filter the DataFrame based on alcohol interaction
        filtered_df = filtered_df[filtered_df['alcohol'].isin(alcohol)]
        
    if age < 10:
        # Filter dataset for users under 10 with at least 5 activity values
        filtered_df = filtered_df.nsmallest(5, 'activity')
        
    elif 10 <= age <= 15:
        # Filter dataset for users between 10 and 15 with at least 10 activity values
        filtered_df = filtered_df.nsmallest(10, 'activity')
    
    # Print the resulting recommendations
    print(filtered_df[:10])

probability = 50  
age = int(input("What is your age? "))

if(age>50):
    print("PLEASE GO TO A DOCTOR....BOODAAA admi he re thuuu!!!")
else:
    gender = input("What is your gender? ")
    if gender.lower() == "female":
        pregnant = input('Are you currently pregnant? (YES/NO): ')
        allowed_pregnancy_category=None
        if pregnant.upper() == 'YES':
            a=input("Which trimester are you in? (First/Second/Third)-mention(1/2/3):")
            if(a=='1'):
                allowed_pregnancy_category = ['A','B','C','D']

            elif(a=='2' or a=='3'):
                if(a=='2'):
                    allowed_pregnancy_category = ['A','B','C']
                else:
                    print('PLS GO TO DOCTOR !!!')
        
    else:
        allowed_pregnancy_category = ['A','B','C','D','N','X']



    if int(age) > 16 :
        alcohol_drinking = input("Do you drink alcohol? (YES/NO) ")
        if(alcohol_drinking=='YES'):
            alcohol=['N']
        else:
            alcohol=['X','N']
    else:
        alcohol=None
        


    if probability < 30:
        # Symptoms as input
        symptoms = input("Please enter your symptoms, separated by commas: ")
        duration = int(input("How long have you been experiencing symptoms? (in days)"))

    else:
        # Disease as input
        disease = input("Please enter the name of the disease: ")
        duration = int(input("How long have you been facing this disease? (in days)"))
        if(duration>15):
            print('pls go to DOCTOR')
            gotohospital=input('want to know nearest hospital:YES/NO')
            print("go to this hospital")
        elif(duration>7):
            print(f'------As u r facing this disease for {duration} days,we recommend to go to DOCTOR------')
            recmedicine(disease,age,gender,allowed_pregnancy_category,alcohol,duration)
        else:
            recmedicine(disease,age,gender,allowed_pregnancy_category,alcohol,duration)
# Out:
# What is your age? 10
# What is your gender? male
# Please enter the name of the disease: Acne
# How long have you been facing this disease? (in days)3
# Acne 10 male ['A', 'B', 'C', 'D', 'N', 'X'] None 3
#              drug_name medical_condition  activity  rx_otc pregnancy_category  \
# 110           Acetoxyl              Acne         0  Rx/OTC                  C
# 111            Acne-10              Acne         0     OTC                  C
# 112         Acne-Clear              Acne         0      Rx                  C
# 113            Acnevir              Acne         0  Rx/OTC                  C
# 114            Acnomel              Acne         0     OTC                  N
# 115  Acnomel Acne Mask              Acne         0  Rx/OTC                  C
# 116       Acnomel BP 5              Acne         0  Rx/OTC                  C
# 117            Aktipak              Acne         0      Rx                  C
# ...
